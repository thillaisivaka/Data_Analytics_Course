# %% [markdown]
# <a href="https://colab.research.google.com/github/thillaisivaka/Data_Analytics_Course/blob/main/data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import kagglehub

path = kagglehub.dataset_download("brendan45774/test-file")

print(path)
# Out:
# Using Colab cache for faster access to the 'test-file' dataset.
# /kaggle/input/test-file

# %%
# Import libraries
import pandas as pd
import matplotlib.pyplot as plt

# Read CSV file
df = pd.read_csv("Salary_Data.csv")

# Display first 5 rows
print("First 5 Records")
print(df.head())

# Dataset information
print("\nDataset Information")
print(df.info())

# Statistical summary
print("\nStatistical Summary")
print(df.describe())

# Check missing values
print("\nMissing Values")
print(df.isnull().sum())

# Plot Salary vs Experience
plt.figure(figsize=(8,5))
plt.scatter(df["YearsExperience"], df["Salary"])
plt.title("Salary vs Years of Experience")
plt.xlabel("Years of Experience")
plt.ylabel("Salary")
plt.grid(True)
plt.show()
# Out:
# First 5 Records
#    YearsExperience  Salary
# 0              1.1   39343
# 1              1.3   46205
# 2              1.5   37731
# 3              2.0   43525
# 4              2.2   39891
#
# Dataset Information
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  30 non-null     float64
#  1   Salary           30 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 612.0 bytes
# None
#
# Statistical Summary
#        YearsExperience         Salary
# count        30.000000      30.000000
# mean          5.313333   76003.000000
# std           2.837888   27414.429785
# min           1.100000   37731.000000
# 25%           3.200000   56720.750000
# 50%           4.700000   65237.000000
# 75%           7.700000  100544.750000
# max          10.500000  122391.000000
#
# Missing Values
# ...

# %%
# Import libraries
import pandas as pd
import matplotlib.pyplot as plt

# Read the CSV file
df = pd.read_csv("Salary_Data.csv")

# Draw Scatter Plot
plt.scatter(df["YearsExperience"], df["Salary"])

# Give title
plt.title("Salary vs Experience")

# X-axis label
plt.xlabel("Years of Experience")

# Y-axis label
plt.ylabel("Salary")

# Display graph
plt.show()

# %%
# Import libraries
import pandas as pd
import matplotlib.pyplot as plt

# Read CSV file
df = pd.read_csv("Salary_Data.csv")

# Scatter Plot
plt.scatter(df["YearsExperience"], df["Salary"])

# Title
plt.title("Salary vs Experience")

# X-axis label
plt.xlabel("Years of Experience")

# Y-axis label
plt.ylabel("Salary")

# Display all experience values on X-axis
plt.xticks(range(1, 11))

# Show graph
plt.show()

# %% [markdown]
# # **Line Plot**

# %%
# Import libraries
import pandas as pd
import matplotlib.pyplot as plt

# Read CSV file
df = pd.read_csv("/content/Salary_Data.csv")

# Line Plot
plt.plot(df["YearsExperience"], df["Salary"])

# Title
plt.title("Salary vs Experience")

# X-axis label
plt.xlabel("Years of Experience")

# Y-axis label
plt.ylabel("Salary")

# Display all experience values on X-axis
plt.xticks(range(1, 11))

# Show graph
plt.show()

# %% [markdown]
# # **Bar Chart**

# %%
# Import libraries
import pandas as pd
import matplotlib.pyplot as plt

# Read CSV file
df = pd.read_csv("/content/Salary_Data.csv")

# Bar Plot
plt.bar(df["YearsExperience"], df["Salary"])
#plt.barh(df["YearsExperience"], df["Salary"])

# Title
plt.title("Salary vs Experience")

# X-axis label
plt.xlabel("Years of Experience")

# Y-axis label
plt.ylabel("Salary")

# Display all experience values on X-axis
plt.xticks(range(1, 11))

# Show graph
plt.show()

# %%
# Import libraries
import pandas as pd
import matplotlib.pyplot as plt

# Read CSV file
df = pd.read_csv("/content/Salary_Data.csv")

# Bar Plot
#plt.bar(df["YearsExperience"], df["Salary"])
plt.barh(df["YearsExperience"], df["Salary"])

# Title
plt.title("Salary vs Experience")

# X-axis label
plt.xlabel("Years of Experience")

# Y-axis label
plt.ylabel("Salary")

# Display all experience values on X-axis
plt.xticks(range(1, 11))

# Show graph
plt.show()
